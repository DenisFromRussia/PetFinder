# %%
from models import db
import pandas as pd
from models import Animal
from datetime import datetime

# %%
db.create_all()

# %%
df = pd.read_excel('Data set.xlsx', skiprows=1, index_col=0)

df_cols = [
    'карточка учета животного №', 'вид ', 'возраст, год', 'вес, кг',
    'кличка', 'пол', 'порода', 'окрас', 'шерсть', 'уши', 'адрес приюта',
    'дата поступления в приют', 'Социализировано (да/нет)'
]

df = df[df_cols]
df['дата поступления в приют'] = pd.to_datetime(df['дата поступления в приют'], errors='coerce')
df = df.dropna()

# %%
for _, row in df.iterrows():
    a = Animal(
        name=row['кличка'],
        card=row['карточка учета животного №'],
        animal=row['вид '],
        year=row['возраст, год'],
        weight=row['вес, кг'],
        male=row['пол'],
        breed=row['порода'],
        color=row['окрас'],
        swool=row['шерсть'],
        ear=row['уши'],
        address=row['адрес приюта'],
        date=row['дата поступления в приют'],
        is_social=row['Социализировано (да/нет)']
    )
    db.session.add(a)
    db.session.commit()

# %%
#tasks = Animal.query.all()
#for task in tasks:
#    print(task.date, task.name, task.breed, task.id)

# %%
df = pd.read_sql_table('animals', con=db.engine)
df
# Out:
#       id        name      card   animal  year weight     male  breed  \
# 0      1      Варя 2  1665з-20   собака  2016   25.0  женский  метис
# 1      2        Фира  1663з-20   собака  2010   16.0  женский  метис
# 2      3      Таисия  1616з-20   собака  2019   17.0  женский  метис
# 3      4       Роллс  1666з-20   собака  2017   28.0  мужской  метис
# 4      5        Рама  1664з-20  собака   2015   25.0  мужской  метис
# ..   ...         ...       ...      ...   ...    ...      ...    ...
# 212  213  без клички       188   собака  2018   20.0  женский  метис
# 213  214  без клички       189   собака  2017   20.0  мужской  метис
# 214  215  без клички       190   собака  2015   20.0  мужской  метис
# 215  216  без клички       191   собака  2019   25.0  мужской  метис
# 216  217  без клички       192   собака  2018   30.0  мужской  метис
#
#                  color     swool          ear  \
# 0               черный  короткая  полустоячие
# 1                рыжий  короткая  полустоячие
# 2     темно-коричневый  короткая  полустоячие
# 3               черный  короткая  полустоячие
# 4    светло-коричневый  короткая  полустоячие
# ..                 ...       ...          ...
# 212              рыжий  короткая  полустоячие
# 213  светло-коричневый  короткая      висячие
# 214          чепрачный  короткая      висячие
# 215           кремовый   длинная  полустоячие
# 216           кремовый   гладкая  полустоячие
#
#                                           address       date is_social
# 0    г.Москва, Зеленоград, Фирсановское ш., вл.5А 2020-07-29        да
# 1    г.Москва, Зеленоград, Фирсановское ш., вл.5А 2020-07-20       нет
# 2    г.Москва, Зеленоград, Фирсановское ш., вл.5А 2020-03-19        да
# 3    г.Москва, Зеленоград, Фирсановское ш., вл.5А 2020-08-10       нет
# 4    г.Москва, Зеленоград, Фирсановское ш., вл.5А 2020-07-29       нет
# ..                                            ...        ...       ...
# 212           г.Москва, Проектируемый проезд, 727 2020-04-17        да
# 213           г.Москва, Проектируемый проезд, 727 2020-05-20       нет
# 214           г.Москва, Проектируемый проезд, 727 2020-03-24        да
# 215           г.Москва, Проектируемый проезд, 727 2020-04-17       нет
# 216           г.Москва, Проектируемый проезд, 727 2020-04-17        да
#
# [217 rows x 14 columns]
